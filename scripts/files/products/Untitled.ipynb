# %%
import pandas as pd

df = pd.read_csv("0009265995_TS_ALL_070817_CLEAN.csv", index_col=0)

# %%
df.loc[df['category'] == ' ']
# Out:
# Empty DataFrame
# Columns: [brand, model, partner_price, retail_price, category]
# Index: []

# %%
df.loc[df['category'] == 'DELETE']
# Out:
#         brand              model  partner_price  retail_price category
# 189     Cisco  STK-RACKMNT-2955=           75.0        125.00   DELETE
# 224     Cisco     SPVAC-C7416-S=          155.4        259.00   DELETE
# 430     Cisco  ACE-AP-SSL-05K-K9         3000.0       5000.00   DELETE
# 431     Cisco      ACE-AP-02-LIC            NaN      39995.00   DELETE
# 433     Cisco  ACE-4710-02-K9-RF        14398.2      23997.00   DELETE
# 435     Cisco        ACE-04G-LIC            NaN      39995.00   DELETE
# 436     Cisco      ACC-WPNL-KIT=           33.8         65.00   DELETE
# 437     Cisco       ACC-RPS2300=          150.0        250.00   DELETE
# 438     Cisco        ACC-KIT-T1=           30.0         50.00   DELETE
# 449     Cisco  ACS-4330-FANASSY=          300.0        500.00   DELETE
# 450     Cisco    ACS-4320-RM-19=           69.0        115.00   DELETE
# 451     Cisco  ACS-4320-FANASSY=          300.0        500.00   DELETE
# ...

# %%
df.shape
# Out:
# (53304, 5)
